# %%
#train:2000장
#val:1000장
# test:22장

# %%
# 데이터 경로 지정
train_dir="/content/drive/MyDrive/인공지능 사관학교/딥러닝/사물지능 딥러닝/data/dogs_vs_cats_small/train"
val_dir="/content/drive/MyDrive/인공지능 사관학교/딥러닝/사물지능 딥러닝/data/dogs_vs_cats_small/validation"
test_dir="/content/drive/MyDrive/인공지능 사관학교/딥러닝/사물지능 딥러닝/data/dogs_vs_cats_small/test"

# %%
import os
print(len(os.listdir(train_dir)))
print(len(os.listdir(val_dir)))
print(len(os.listdir(test_dir)))
# Out:
# 2
# 2
# 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 하나의 변수에 이미지 파일 전부다 합치기
# 픽셀값 0~255 >0~1
# 이미지 크기 동일하게 만들어주기(150,150)
#라벨링
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#픽셀값 변환
train_gen=ImageDataGenerator(rescale=1./255)
test_gen=ImageDataGenerator(rescale=1./255)
val_gen=ImageDataGenerator(rescale=1./255)

# %%
#flow_from_directory()
train_generator=train_gen.flow_from_directory(
    train_dir, # train이미지의 경로 
    target_size=(150,150), # 변환할 이미지의 크기
    batch_size= 100, #한번에 변환할 이미지 개수
    class_mode='binary'# 라벨링 진행, 이진분류가 아니라 다중분류라면? categorical: 다중 분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_generator=test_gen.flow_from_directory(
    test_dir, # train이미지의 경로 
    target_size=(150,150), # 변환할 이미지의 크기
    batch_size= 100, #한번에 변환할 이미지 개수
    class_mode='binary'# 라벨링 진행, 이진분류가 아니라 다중분류라면? categorical: 다중 분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
)
# Out:
# Found 22 images belonging to 2 classes.

# %%
val_generator=val_gen.flow_from_directory(
    val_dir, # train이미지의 경로 
    target_size=(150,150), # 변환할 이미지의 크기
    batch_size= 100, #한번에 변환할 이미지 개수
    class_mode='binary'# 라벨링 진행, 이진분류가 아니라 다중분류라면? categorical: 다중 분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
)
# Out:
# Found 1000 images belonging to 2 classes.

# %%
# 라벨링 결과 확인 
print(train_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
# cnn 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,MaxPool2D,Flatten,Dropout

# %%
# 딥러닝 모델 생성
model1 = Sequential()
# 입력층, 특징추출부
model1.add(Conv2D(
    filters = 32, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))
model1.add(MaxPool2D(
    pool_size = (2,2)
))
model1.add(Conv2D(
    filters = 64, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))
model1.add(MaxPool2D(
    pool_size = (2,2)
))
################특징 추출부 끝###############
model1.add(Flatten())
################분류부 시작#################
# 위에서 특징을 추출했기때문에 층을 깊게 쌓지 않아도됨
model1.add(Dense(units = 256, activation = 'relu'))
model1.add(Dropout(0.4))

# 출력층
model1.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# 모델 컴파일 하기
model1.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']

)

# %%
model1.fit_generator(generator=train_aug_generator,
                     epochs=20,validation_data = val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/20
# 20/20 [==============================] - 91s 5s/step - loss: 0.6931 - accuracy: 0.4945 - val_loss: 0.6922 - val_accuracy: 0.4970
# Epoch 2/20
# 20/20 [==============================] - 105s 5s/step - loss: 0.6931 - accuracy: 0.5155 - val_loss: 0.6922 - val_accuracy: 0.5560
# Epoch 3/20
# 20/20 [==============================] - 91s 5s/step - loss: 0.6909 - accuracy: 0.5365 - val_loss: 0.6893 - val_accuracy: 0.5720
# Epoch 4/20
# 20/20 [==============================] - 92s 5s/step - loss: 0.6886 - accuracy: 0.5695 - val_loss: 0.6829 - val_accuracy: 0.5840
# Epoch 5/20
# 20/20 [==============================] - 93s 5s/step - loss: 0.6780 - accuracy: 0.5730 - val_loss: 0.6718 - val_accuracy: 0.5830
# Epoch 6/20
# ...

# %%
#과대적합이 관찰되었다. ( 정확도가 100%인데 평가 데이터에서는 제대로 평가하지 못한다)
#해결방법
#학습데이터 증가
#딥러닝 모델 재설계-> dropout()
#학습데이터 augmentation(확장): 기존의 이미지에 변화를 줘서 이미지를 사용

# %%
# 이미지 확장(증식)
train_aug=ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    shear_range = 0.1,
    zoom_range = 0.1,
    horizontal_flip = True,
    fill_mode = 'nearest' # 비어있는 부분을 가장 가까이에 있는 값으로 채우기 
)

train_aug_generator=train_aug.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=100,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
# 전이학습 
# 누군가가 만들어 놓은 모델 가져오기 
# 특성 추출 방식
from tensorflow.keras.applications import VGG16


conv_base=VGG16(
    weights= 'imagenet', # imagenet에서 사용한 가중치 가져오기
    include_top=False, # 분류기를 사용할것인가? (아냐 분류기 우리가 직접 만들거야)
     input_shape=(150,150, 3)
  
)
# Out:
# ...
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
# ...

# %%
# 동결
# 가중치가 갱신되는 것을 막는것 
# 학습가능한 가중치의 갯수확인 
len(conv_base.trainable_weights)
# Out:
# 26

# %%
#VGG16 전체 층에 대해 동결
conv_base.trainable=False

# %%
# 동결된 conv를 사용해서 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,MaxPool2D,Flatten,Dropout

model2=Sequential()
model2.add(conv_base) # 전이학습할 모델의 특성 추출부 사용하기 

model2.add(Flatten()) 
model2.add(Dense(units= 256, activation='relu'))
# 출력층 
model2.add(Dense(units= 1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  dense_10 (Dense)            (None, 256)               2097408
#
#  dense_11 (Dense)            (None, 1)                 257
#
# ...
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %%
model2.fit_generator(generator=train_aug_generator, epochs=20, validation_data=val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.6932 - accuracy: 0.4940 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 2/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.4880 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.6932 - accuracy: 0.4970 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 6/20
# ...

# %%
# 미세조정방식

# %%
#model2에서 학습가능한 가중치의 개수
len(model2.trainable_weights)
# Out:
# 4

# %%
conv_base.summary()

# %%
from tensorflow.keras.applications import VGG16


conv_base=VGG16(
    weights= 'imagenet', # imagenet에서 사용한 가중치 가져오기
    include_top=False, # 분류기를 사용할것인가? (아냐 분류기 우리가 직접 만들거야)
     input_shape=(150,150, 3)
  
)

# %%
#block5_conv1~3층을 학습 시켜보자
set_trainable=False

# block5_conv1이하의 층들을 학습가능하도록 만듬  
for layer in conv_base.layers:
  if layer.name== 'block5_conv1':
    set_trainable=True

  if set_trainable== True:
    layer.trainable=True

  else:
    layer.trainable=False

# %%
# 동결된 conv를 사용해서 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,MaxPool2D,Flatten,Dropout

model2=Sequential()
model2.add(conv_base) # 전이학습할 모델의 특성 추출부 사용하기 

model2.add(Flatten()) 
model2.add(Dense(units= 256, activation='relu'))
# 출력층 
model2.add(Dense(units= 1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 8192)              0
#
#  dense_8 (Dense)             (None, 256)               2097408
#
#  dense_9 (Dense)             (None, 1)                 257
#
# ...
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
#model2에서 학습가능한 가중치의 개수
len(model2.trainable_weights)
# Out:
# 10

# %%
model2.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

# %%
model2.fit_generator(generator=train_aug_generator, epochs=20, validation_data=val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """Entry point for launching an IPython kernel.
# Epoch 1/20
# 20/20 [==============================] - 23s 1s/step - loss: 1.5973 - accuracy: 0.5220 - val_loss: 0.6932 - val_accuracy: 0.4990
# Epoch 2/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.7072 - accuracy: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/20
# ...
